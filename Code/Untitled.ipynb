# %%
import patoolib
import os

# %%
com_path = r'../dailies/'
uncom_path = r'../Uncompressed'/

# %%
patoolib.extract_archive(f'{com_path}2020-08-31/2020-08-31-dataset.tsv.gz')
# Out:
# patool: Extracting ../dailies/2020-08-31/2020-08-31-dataset.tsv.gz ...
# patool: ... ../dailies/2020-08-31/2020-08-31-dataset.tsv.gz extracted to `2020-08-31-dataset.tsv'.
# '2020-08-31-dataset.tsv'

# %%
os.listdir(com_path)
# Out:
# ['2020-03-22',
#  '2020-03-23',
#  '2020-03-24',
#  '2020-03-25',
#  '2020-03-26',
#  '2020-03-27',
#  '2020-03-28',
#  '2020-03-29',
#  '2020-03-30',
#  '2020-03-31',
#  '2020-04-01',
#  '2020-04-02',
#  '2020-04-03',
#  '2020-04-04',
#  '2020-04-05',
#  '2020-04-06',
#  '2020-04-07',
#  '2020-04-08',
#  '2020-04-09',
#  '2020-04-10',
#  '2020-04-11',
#  '2020-04-12',
#  '2020-04-13',
#  '2020-04-14',
#  '2020-04-15',
#  '2020-04-16',
#  '2020-04-17',
#  '2020-04-18',
#  '2020-04-19',
#  '2020-04-20',
#  '2020-04-21',
#  '2020-04-22',
#  '2020-04-23',
#  '2020-04-24',
#  '2020-04-25',
#  '2020-04-26',
#  '2020-04-27',
#  '2020-04-28',
#  '2020-04-29',
#  '2020-04-30',
#  '2020-05-01',
#  '2020-05-02',
#  '2020-05-03',
#  '2020-05-04',
#  '2020-05-05',
#  '2020-05-06',
#  '2020-05-07',
#  '2020-05-08',
#  '2020-05-09',
#  '2020-05-10',
#  '2020-05-11',
#  '2020-05-12',
#  '2020-05-13',
#  '2020-05-14',
#  '2020-05-15',
#  '2020-05-16',
#  '2020-05-17',
#  '2020-05-18',
# ...
